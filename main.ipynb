# %%
###########################
# 라이브러리 사용
import pandas as pd
 
###########################
# 파일로부터 데이터 읽어오기
파일경로 = 'https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/lemonade.csv'
레모네이드 = pd.read_csv(파일경로)
 
파일경로 = 'https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/boston.csv'
보스턴 = pd.read_csv(파일경로)
 
파일경로 = 'https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/iris.csv'
아이리스 = pd.read_csv(파일경로)
 
###########################
# 데이터의 모양확인
print(레모네이드.shape)
print(보스턴.shape)
print(아이리스.shape)
 
###########################
# 데이터 칼럼이름 확인
print(레모네이드.columns)
print(보스턴.columns)
print(아이리스.columns)
 
 
###########################
# 독립변수와 종속변수 분리
독립 = 레모네이드[['온도']]
종속 = 레모네이드[['판매량']]
print(독립.shape, 종속.shape)
 
독립 = 보스턴[['crim', 'zn', 'indus', 'chas', 'nox', 
            'rm', 'age', 'dis', 'rad', 'tax',
            'ptratio', 'b', 'lstat']]
종속 = 보스턴[['medv']]
print(독립.shape, 종속.shape)
 
독립 = 아이리스[['꽃잎길이', '꽃잎폭', '꽃받침길이', '꽃받침폭']]
종속 = 아이리스[['품종']]
print(독립.shape, 종속.shape)
 
 
###########################
# 각각의 데이터 확인해보기
print(레모네이드.head())
print(보스턴.head())
print(아이리스.head())
# Out:
# (6, 2)
# (506, 14)
# (150, 5)
# Index(['온도', '판매량'], dtype='object')
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')
# Index(['꽃잎길이', '꽃잎폭', '꽃받침길이', '꽃받침폭', '품종'], dtype='object')
# (6, 1) (6, 1)
# (506, 13) (506, 1)
# (150, 4) (150, 1)
#    온도  판매량
# 0  20   40
# 1  21   42
# 2  22   44
# 3  23   46
# 4  24   48
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2
#    꽃잎길이  꽃잎폭  꽃받침길이  꽃받침폭      품종
# 0   5.1  3.5    1.4   0.2  setosa
# 1   4.9  3.0    1.4   0.2  setosa
# 2   4.7  3.2    1.3   0.2  setosa
# 3   4.6  3.1    1.5   0.2  setosa
# 4   5.0  3.6    1.4   0.2  setosa

# %%
###########################
# 라이브러리 사용
import tensorflow as tf
import pandas as pd

###########################
# 데이터를 준비합니다.
path = 'https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/lemonade.csv'
lemonade = pd.read_csv(path)
lemonade.head()
# 종속변수, 독립변수
alone = lemonade[['온도']]
depand = lemonade[['판매량']]
print(alone.shape, depand.shape)

###########################
# 모델을 만듭니다.
X = tf.keras.layers.Input(shape=[1])
Y = tf.keras.layers.Dense(1)(X)
model = tf.keras.models.Model(X, Y)
model.compile(loss='mse')

###########################
# 모델을 학습시킵니다. 
model.fit(alone, depand, epochs=1000, verbose=0) # epochs: leaning count
model.fit(alone, depand, epochs=10)

###########################
# 모델을 이용합니다. 
print(model.predict(alone))
print(model.predict([[15]]))
# Out:
# (6, 1) (6, 1)
# Epoch 1/10
# 1/1 [==============================] - 0s 2ms/step - loss: 2303.0371
# Epoch 2/10
# 1/1 [==============================] - 0s 2ms/step - loss: 2300.7861
# Epoch 3/10
# 1/1 [==============================] - 0s 2ms/step - loss: 2298.5361
# Epoch 4/10
# 1/1 [==============================] - 0s 2ms/step - loss: 2296.2874
# Epoch 5/10
# 1/1 [==============================] - 0s 2ms/step - loss: 2294.0398
# Epoch 6/10
# 1/1 [==============================] - 0s 2ms/step - loss: 2291.7932
# Epoch 7/10
# 1/1 [==============================] - 0s 2ms/step - loss: 2289.5476
# Epoch 8/10
# 1/1 [==============================] - 0s 3ms/step - loss: 2287.3035
# Epoch 9/10
# 1/1 [==============================] - 0s 1ms/step - loss: 2285.0603
# Epoch 10/10
# 1/1 [==============================] - 0s 2ms/step - loss: 2282.8181
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/t9/f57x2g9558v56xld31r68qsr0000gn/T/ipykernel_5147/886000676.py in <module>
#      24 # 모델을 학습시킵니다.
#      25 model.fit(alone, depand, epochs=1000, verbose=0) # epochs: leaning count
# ---> 26 model.fit(alone, depand, epochs=10)
#      27
#      28 ###########################
#
# /usr/local/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1227           epoch_logs.update(val_logs)
#    1228
# -> 1229         callbacks.on_epoch_end(epoch, epoch_logs)
#    1230         training_logs = epoch_logs
#    1231         if self.stop_training:
#
# /usr/local/lib/python3.9/site-packages/tensorflow/python/keras/callbacks.py in on_epoch_end(self, epoch, logs)
#     433     logs = self._process_logs(logs)
#     434     for callback in self.callbacks:
# --> 435       callback.on_epoch_end(epoch, logs)
#     436
#     437   def on_train_batch_begin(self, batch, logs=None):
#
# /usr/local/lib/python3.9/site-packages/tensorflow/python/keras/callbacks.py in on_epoch_end(self, epoch, logs)
#    1038
#    1039   def on_epoch_end(self, epoch, logs=None):
# -> 1040     self._finalize_progbar(logs, self._train_step)
#    1041
#    1042   def on_test_end(self, logs=None):
#
# /usr/local/lib/python3.9/site-packages/tensorflow/python/keras/callbacks.py in _finalize_progbar(self, logs, counter)
#    1111       self.target = counter or self.seen
#    1112       self.progbar.target = self.target
# -> 1113     self.progbar.update(self.target, list(logs.items()), finalize=True)
#    1114
#    1115
#
# /usr/local/lib/python3.9/site-packages/tensorflow/python/keras/utils/generic_utils.py in update(self, current, values, finalize)
#     965
#     966       sys.stdout.write(info)
# --> 967       sys.stdout.flush()
#     968
#     969     elif self.verbose == 2:
#
# ~/Library/Python/3.9/lib/python/site-packages/ipykernel/iostream.py in flush(self)
#     454                 self.pub_thread.schedule(evt.set)
#     455                 # and give a timeout to avoid
# --> 456                 if not evt.wait(self.flush_timeout):
#     457                     # write directly to __stderr__ instead of warning because
#     458                     # if this is happening sys.stderr may be the problem.
#
# /usr/local/Frameworks/Python.framework/Versions/3.9/lib/python3.9/threading.py in wait(self, timeout)
#     572             signaled = self._flag
#     573             if not signaled:
# --> 574                 signaled = self._cond.wait(timeout)
#     575             return signaled
#     576
#
# /usr/local/Frameworks/Python.framework/Versions/3.9/lib/python3.9/threading.py in wait(self, timeout)
#     314             else:
#     315                 if timeout > 0:
# --> 316                     gotit = waiter.acquire(True, timeout)
#     317                 else:
#     318                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
import pandas as pd

# load data from path
path = 'https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/lemonade.csv'
lemonade = pd.read_csv(path)

path = 'https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/boston.csv'
bosthon = pd.read_csv(path)

path = 'https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/iris.csv'
iris = pd.read_csv(path)

# show data from shape

print(lemonade.shape)
print(bosthon.shape)
print(iris.shape)

#print column name
print(lemonade.columns)
print(bosthon.columns)
print(iris.columns)

# divide alone, depand

alone = lemonade[['온도']]
depand = lemonade[['판매량']]
print(alone.shape, depand.shape)

alone = bosthon[['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'b', 'lstat']]
depand = bosthon[['medv']]
print(alone.shape, depand.shape)

alone = iris[['꽃잎길이', '꽃잎폭', '꽃받침길이', '꽃받침폭']]
depand = iris[['품종']]
print(alone.shape, depand.shape)

lemonade.head()
bosthon.head()
iris.head()
# Out:
# (6, 2)
# (506, 14)
# (150, 5)
# Index(['온도', '판매량'], dtype='object')
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')
# Index(['꽃잎길이', '꽃잎폭', '꽃받침길이', '꽃받침폭', '품종'], dtype='object')
# (6, 1) (6, 1)
# (506, 13) (506, 1)
# (150, 4) (150, 1)
#    꽃잎길이  꽃잎폭  꽃받침길이  꽃받침폭      품종
# 0   5.1  3.5    1.4   0.2  setosa
# 1   4.9  3.0    1.4   0.2  setosa
# 2   4.7  3.2    1.3   0.2  setosa
# 3   4.6  3.1    1.5   0.2  setosa
# 4   5.0  3.6    1.4   0.2  setosa
